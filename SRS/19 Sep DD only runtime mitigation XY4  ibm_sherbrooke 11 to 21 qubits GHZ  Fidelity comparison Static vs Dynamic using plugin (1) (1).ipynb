# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.transpiler import InstructionProperties
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler import PassManager

service = QiskitRuntimeService()

# %%
backend1 = service.backend("ibm_sherbrooke") 
target = backend1.target
basis_gates = list(target.operation_names)

# %%
def get_ghz_circ_static(num_qubit):
    if num_qubit%2==1:                                                     #odd no of qubits
        qr=QuantumRegister(num_qubit)
        cr2=ClassicalRegister(num_qubit,name="cr2")                     
        qc=QuantumCircuit(qr,cr2)
        mid_qubit_index=int((num_qubit-1)/2)
        qc.h(mid_qubit_index)
        for i in range(mid_qubit_index,num_qubit-1):
            qc.cx(i,i+1)
            qc.cx(num_qubit-i-1,num_qubit-i-2)
        

    else:                                                                    #even no of qubits
        qr=QuantumRegister(num_qubit)
        cr2=ClassicalRegister(num_qubit,name="cr2")                     
        qc=QuantumCircuit(qr,cr2)
        mid_qubit_index=int((num_qubit-2)/2)
        qc.h(mid_qubit_index)
        for i in range(mid_qubit_index,num_qubit-2):
            qc.cx(i,i+1)
            qc.cx(num_qubit-1-i-1,num_qubit-i-3)
        qc.cx(num_qubit-2,num_qubit-1)
    for i in range(num_qubit):
        qc.measure(qr[i],cr2[i])
    return qc

# %%
qc = get_ghz_circ_static(num_qubit=7)
qc.draw("mpl")

# %%
#dynamic circuit using qubit-reuse in aersimulator

# %%
def get_ghz_circ_static_1(num_qubit):
    if num_qubit%2==1:                                                     #odd no of qubits
        qr=QuantumRegister(num_qubit)
        cr2=ClassicalRegister(num_qubit,name="cr2")                     
        qc=QuantumCircuit(qr,cr2)
        mid_qubit_index=int((num_qubit-1)/2)
        qc.h(mid_qubit_index)
        for i in range(mid_qubit_index,num_qubit-1):
            qc.cx(i,i+1)
            qc.cx(num_qubit-i-1,num_qubit-i-2)
        

    else:                                                                    #even no of qubits
        qr=QuantumRegister(num_qubit)
        cr2=ClassicalRegister(num_qubit,name="cr2")                     
        qc=QuantumCircuit(qr,cr2)
        mid_qubit_index=int((num_qubit-2)/2)
        qc.h(mid_qubit_index)
        for i in range(mid_qubit_index,num_qubit-2):
            qc.cx(i,i+1)
            qc.cx(num_qubit-1-i-1,num_qubit-i-3)
        qc.cx(num_qubit-2,num_qubit-1)
    for i in range(num_qubit):
        qc.measure(qr[i],cr2[i])
    return qc

# %%
#creating dynamic circuit from a separate static circuit
from qiskit_aer import AerSimulator
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

def get_ghz_circ_dynamic_2(num_qubit):
    qc=get_ghz_circ_static_1(num_qubit)
    aer_sim = AerSimulator()
    pm = generate_preset_pass_manager(backend=aer_sim, optimization_level=1, init_method="qubit_reuse")
    transpiled_qc = pm.run(qc)
    
    return transpiled_qc

# %%
qc = get_ghz_circ_dynamic_2(num_qubit=7)
qc.draw("mpl")

# %%
#Creating list of circuits[Static_1, Dynamic1_1, Dynamic2_1, Static_1, Dynamic1_1, Dynamic2_1,...,Static_2, Dynamic1_2, Dynamic2_2, Static_2, Dynamic1_2, Dynamic2_2,...] i.e. some copies of each of them

min_qubit=11
max_num_qubit=21
copies=4

#qc_list_dynamic_1=[]
#qc_list_dynamic_2=[]
#qc_list_static=[]
#observables=[]

qc_list=[]
num_qubit_list=list(range(min_qubit,max_num_qubit+1,2))
for num_qubit in num_qubit_list:
    for i in range(copies):
        qc_list.append(get_ghz_circ_static(num_qubit))
        #qc_list.append(get_ghz_circ_dynamic_1(num_qubit))
        qc_list.append(get_ghz_circ_dynamic_2(num_qubit))
print(num_qubit_list)
# Out:
# [11, 13, 15, 17, 19, 21]

# %%
#Ideal Simulation with AerSimulator
from qiskit_aer import AerSimulator
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, SamplerV2 as Sampler
 
aer_sim = AerSimulator()
pm = generate_preset_pass_manager(backend=aer_sim, optimization_level=2,basis_gates=basis_gates)
qc_transpiled_list=[]

qc_transpiled_list_ideal = pm.run(qc_list)

# %%
sampler = Sampler(backend=aer_sim)
result_ideal = sampler.run(qc_transpiled_list_ideal).result()

# %%
print(result_ideal)
len(result_ideal)
# Out:
# PrimitiveResult([PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(c48=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(c50=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(c52=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(c54=BitArray(<shape=(), num_shots=1024, num_bits=11>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(c56=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(c58=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(c60=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(c62=BitArray(<shape=(), num_shots=1024, num_bits=13>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(c64=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(c66=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(c68=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(c70=BitArray(<shape=(), num_shots=1024, num_bits=15>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(c72=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(c74=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(c76=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(c78=BitArray(<shape=(), num_shots=1024, num_bits=17>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(c80=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(c82=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(c84=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(c86=BitArray(<shape=(), num_shots=1024, num_bits=19>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(c88=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(c90=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(c92=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))), PubResult(data=DataBin(c94=BitArray(<shape=(), num_shots=1024, num_bits=21>)))], metadata={})
# 48

# %%
# For getting list of ideal counts (argument required for Fidelity)
counts_list_ideal=[]
k=24
for i in range(len(num_qubit_list)):  
    for j in range(copies):
        data_static = result_ideal[(2*i*copies)+(2*j)].data    
        #data_dynamic_1 = result_ideal[(3*i*copies)+((3*j)+1)].data 
        data_dynamic_2 = result_ideal[(2*i*copies)+((2*j)+1)].data

        print(data_static)
        #print(data_dynamic_1)
        print(data_dynamic_2)
        
        counts_static=data_static.cr2.get_counts()
        #counts_dynamic_1=data_dynamic_1.cr2.get_counts()
        
        # Replacing 'cr2' with the appropriate attribute if needed
        dynamic_2_attr_name = f'c{2*(k)}'
        if hasattr(data_dynamic_2, dynamic_2_attr_name):
            counts_dynamic_2 = getattr(data_dynamic_2, dynamic_2_attr_name).get_counts()
        else:
            raise AttributeError(f"{dynamic_2_attr_name} not found in data_dynamic_2")
        
        counts_list_ideal.append(counts_static)
        #counts_list_ideal.append(counts_dynamic_1)
        counts_list_ideal.append(counts_dynamic_2)
        k=k+1
# Out:
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c48=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c50=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c52=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c54=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c56=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c58=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c60=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c62=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c64=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c66=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c68=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c70=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c72=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c74=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c76=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c78=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c80=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c82=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c84=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c86=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c88=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c90=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c92=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c94=BitArray(<shape=(), num_shots=1024, num_bits=21>))

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService

 
# Save an IBM Quantum account and set it as your default account.

 
# Load saved credentials
service = QiskitRuntimeService()
backend_name = "ibm_sherbrooke"
service = QiskitRuntimeService()
backend = service.get_backend(backend_name)
pm = generate_preset_pass_manager(optimization_level=2, backend=backend, basis_gates=basis_gates)
qc_transpiled_list = pm.run(qc_list)

# %%
#Executing the circuit
from qiskit_ibm_runtime import SamplerV2 as Sampler

sampler = Sampler(backend=backend)

from qiskit_ibm_runtime import Options
 
# Estimator and Sampler now have different options
options = sampler.options
 
options.dynamical_decoupling.enable = True
options.dynamical_decoupling.sequence_type = 'XY4'
#dynamical_decoupling={'enable':True, 'sequence_type':'XpXm'}
job = sampler.run(qc_transpiled_list,shots=1024)
print(job.job_id())
# Out:
# cvntwbstr1zg00831rf0

# %%
#Post-processing
import matplotlib.pyplot as plt
import statistics
from qiskit_ibm_runtime import QiskitRuntimeService

job_id = 'cvntwbstr1zg00831rf0' #Sherbrooke

service = QiskitRuntimeService()
job = service.job(job_id)
result_real = job.result()

# %%
print(result_real)
len(result_real)
# Out:
# PrimitiveResult([PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c0=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c2=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c4=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c6=BitArray(<shape=(), num_shots=1024, num_bits=11>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c8=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c10=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c12=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c14=BitArray(<shape=(), num_shots=1024, num_bits=13>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c16=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c18=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c20=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c22=BitArray(<shape=(), num_shots=1024, num_bits=15>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c24=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c26=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c28=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c30=BitArray(<shape=(), num_shots=1024, num_bits=17>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(c32=BitArray(<shape=(), num_shots=1024, num_bits=19>)), metadata={'circuit_metadata': {}}), PubResult(data=DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>)), ...
# 48

# %%
#Finding the metrics of the job
result_metric_real=job.metrics()
print(result_metric_real)
# Out:
# {'bss': {'seconds': 304}, 'usage': {'quantum_seconds': 304, 'seconds': 304}, 'timestamps': {'created': '2024-09-19T04:53:04.145Z', 'finished': '2024-09-19T05:01:23.829Z', 'running': '2024-09-19T04:53:05.850Z'}, 'executions': 49152, 'num_circuits': 48, 'num_qubits': [127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127], 'circuit_depths': [54, 209, 56, 217, 56, 217, 54, 217, 62, 256, 66, 256, 61, 256, 61, 256, 68, 311, 68, 303, 62, 303, 68, 303, 72, 350, 70, 358, 71, 358, 69, 358, 68, 405, 74, 397, 72, 405, 73, 397, 77, 444, 79, 444, 76, 452, 70, 444], 'qiskit_version': 'qiskit_ibm_runtime-0.23.0,qiskit-1.1.0*,qiskit_aer-0.14.2*,qiskit_experiments-0.6.1,circuit_knitting_toolbox-0.7.2', 'estimated_start_time': '2024-09-19T04:53:04.898Z', 'estimated_completion_time': '2024-09-19T04:58:08.898Z', 'position_in_queue': None, 'position_in_provider': None}

# %%
# For getting list of real counts of IBM brisbane (argument required for Fidelity)
counts_list_real=[]
k=0
for i in range(len(num_qubit_list)):  
    for j in range(copies):
        data_static = result_real[(2*i*copies)+(2*j)].data    
        #data_dynamic_1 = result_real[(3*i*copies)+((3*j)+1)].data 
        data_dynamic_2 = result_real[(2*i*copies)+((2*j)+1)].data

        print(data_static)
        #print(data_dynamic_1)
        print(data_dynamic_2)
        
        counts_static=data_static.cr2.get_counts()
        #counts_dynamic_1=data_dynamic_1.cr2.get_counts()
        
        # Replacing 'cr3' with the appropriate attribute if needed
        dynamic_2_attr_name = f'c{2*(k)}'
        if hasattr(data_dynamic_2, dynamic_2_attr_name):
            counts_dynamic_2 = getattr(data_dynamic_2, dynamic_2_attr_name).get_counts()
        else:
            raise AttributeError(f"{dynamic_2_attr_name} not found in data_dynamic_2")
        
        counts_list_real.append(counts_static)
        #counts_list_real.append(counts_dynamic_1)
        counts_list_real.append(counts_dynamic_2)
        k=k+1
# Out:
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c0=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c4=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(c6=BitArray(<shape=(), num_shots=1024, num_bits=11>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c8=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c10=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c12=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(c14=BitArray(<shape=(), num_shots=1024, num_bits=13>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c16=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c18=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c20=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(c22=BitArray(<shape=(), num_shots=1024, num_bits=15>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c24=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c26=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c28=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(c30=BitArray(<shape=(), num_shots=1024, num_bits=17>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c32=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c34=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c36=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(c38=BitArray(<shape=(), num_shots=1024, num_bits=19>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c40=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c42=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c44=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(cr2=BitArray(<shape=(), num_shots=1024, num_bits=21>))
# DataBin(c46=BitArray(<shape=(), num_shots=1024, num_bits=21>))

# %%
#Calculation of lists of Fidelity mean and std deviation of real hardware simulation in ibm_sherbrooke
import statistics
from qiskit.quantum_info.analysis import hellinger_fidelity
# We will create 4 lists of Fidelities, for storing mean, std deviation of Fidelity, of copies of a circuit for fixed no of logical qubits
 
Fidelity_mean_static_sherbrooke=[]
#Fidelity_mean_dynamic_1_sherbrooke=[]
Fidelity_mean_dynamic_2_sherbrooke=[]

Fidelity_std_static_sherbrooke=[]
#Fidelity_std_dynamic_1_sherbrooke=[]
Fidelity_std_dynamic_2_sherbrooke=[]

Fidelity_copies_static_sherbrooke=[]
#Fidelity_copies_dynamic_1_sherbrooke=[]
Fidelity_copies_dynamic_2_sherbrooke=[]

for i in range(len(num_qubit_list)):
    
    for j in range(copies):
        
        Fidelity_static= hellinger_fidelity(counts_list_ideal[(2*i*copies)+(2*j)], counts_list_real[(2*i*copies)+(2*j)])
        #Fidelity_dynamic_1=hellinger_fidelity(counts_list_ideal[(3*i*copies)+((3*j)+1)], counts_list_real[(3*i*copies)+((3*j)+1)])
        Fidelity_dynamic_2=hellinger_fidelity(counts_list_ideal[(2*i*copies)+((2*j)+1)], counts_list_real[(2*i*copies)+((2*j)+1)])
        
        Fidelity_copies_static_sherbrooke.append(Fidelity_static)
        #Fidelity_copies_dynamic_1_sherbrooke.append(Fidelity_dynamic_1)
        Fidelity_copies_dynamic_2_sherbrooke.append(Fidelity_dynamic_2)

    
    Fidelity_mean_static_sherbrooke.append(statistics.mean(Fidelity_copies_static_sherbrooke))
    #Fidelity_mean_dynamic_1_sherbrooke.append(statistics.mean(Fidelity_copies_dynamic_1_sherbrooke))
    Fidelity_mean_dynamic_2_sherbrooke.append(statistics.mean(Fidelity_copies_dynamic_2_sherbrooke))
    
    Fidelity_std_static_sherbrooke.append(statistics.stdev(Fidelity_copies_static_sherbrooke))
    #Fidelity_std_dynamic_1_sherbrooke.append(statistics.stdev(Fidelity_copies_dynamic_1_sherbrooke))
    Fidelity_std_dynamic_2_sherbrooke.append(statistics.stdev(Fidelity_copies_dynamic_2_sherbrooke))
    
    Fidelity_copies_static_sherbrooke.clear()
    #Fidelity_copies_dynamic_1_sherbrooke.clear()
    Fidelity_copies_dynamic_2_sherbrooke.clear()

# %%
# Graph plotting
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
#figure(figsize=(16,12), dpi=180)
fig, ax1 = plt.subplots(1, 1, figsize=(12,12))

# Create  data.
ax1.set_xlabel('Number of Qubits in Original GHZ State Circuit',fontsize=20,labelpad=8)
ax1.set_ylabel('Fidelity',fontsize=20,labelpad=8)
#ax1.set_title('ibm_sherbrooke XY4 DD')

x1 = num_qubit_list
y1_static = Fidelity_mean_static_sherbrooke
#y1_dynamic_1 = Fidelity_mean_dynamic_1_sherbrooke
y1_dynamic_2 = Fidelity_mean_dynamic_2_sherbrooke
print(y1_static)
#print(y1_dynamic_1)
print(y1_dynamic_2)

y_error_static =Fidelity_std_static_sherbrooke
#y_error_dynamic_1 =Fidelity_std_dynamic_1_sherbrooke
y_error_dynamic_2 =Fidelity_std_dynamic_2_sherbrooke
print(y_error_static)
#print(y1_dynamic_1)
print(y_error_dynamic_2)
ax1.set_xticks(num_qubit_list)
ax1.plot(x1, y1_static, 'o-',label='Original Circuit')
#ax1.plot(x1, y1_dynamic_1, 'o-',label='dynamic_1')
ax1.plot(x1, y1_dynamic_2, 'o-',label='Qubit Reuse')
"""
ax1.errorbar(x1, y1_static,
			yerr = y_error_static, label='Original Circuit error bar',
			fmt ='o',capsize=5, capthick=3)
#ax1.errorbar(x1, y1_dynamic_1,
			#yerr = y_error_dynamic_1, label='dynamic_1',
			#fmt ='o')
ax1.errorbar(x1, y1_dynamic_2,
			yerr = y_error_dynamic_2, label='Qubit Reuse error bar',
			fmt ='o',capsize=5, capthick=3)

"""
plt.legend()
plt.show()
#ibm sherbrooke XY4DD
# Out:
# [0.6569941565218197, 0.562788759727761, 0.46751864259420994, 0.41435879943053056, 0.20871323933039482, 0.21818053913392388]
# [0.6753480250800856, 0.6094560854821358, 0.5484208294552921, 0.5197211474834664, 0.49575407983832687, 0.4519362809220314]
# [0.09211773820354317, 0.0943900437975101, 0.06247831199758222, 0.08880006983325293, 0.08094575776585243, 0.06526649019397428]
# [0.015734704345823657, 0.007490183973673779, 0.031134069070868124, 0.014050163968802685, 0.01580818594794623, 0.018428751985244112]

# %%
layout_list=[]
for i in range(len(qc_transpiled_list)):
    final_layout = qc_transpiled_list[i]._layout.final_layout
    layout_list.append(final_layout)
print(layout_list)
# Create a dictionary
data = {
    "num_qubits": num_qubit_list,
    "copies":4,
    "layouts": layout_list
}

# Write to JSON file
with open('data19sep.json', 'w') as f:
    json.dump(data, f, indent=4)
# Out:
# [None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 123: Qubit(QuantumRegister(127, 'q'), 124),
# 124: Qubit(QuantumRegister(127, 'q'), 125),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 124: Qubit(QuantumRegister(127, 'q'), 125),
# 123: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 124: Qubit(QuantumRegister(127, 'q'), 125),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 123: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 123: Qubit(QuantumRegister(127, 'q'), 124),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 124: Qubit(QuantumRegister(127, 'q'), 125),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 110),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 110: Qubit(QuantumRegister(127, 'q'), 101),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 123: Qubit(QuantumRegister(127, 'q'), 123),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 125),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 110: Qubit(QuantumRegister(127, 'q'), 101),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 101: Qubit(QuantumRegister(127, 'q'), 110),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 123: Qubit(QuantumRegister(127, 'q'), 123),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 125),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 123: Qubit(QuantumRegister(127, 'q'), 125),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 125: Qubit(QuantumRegister(127, 'q'), 123),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 123: Qubit(QuantumRegister(127, 'q'), 125),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 123: Qubit(QuantumRegister(127, 'q'), 125),
# 125: Qubit(QuantumRegister(127, 'q'), 124),
# 124: Qubit(QuantumRegister(127, 'q'), 123),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# ...
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 124: Qubit(QuantumRegister(127, 'q'), 123),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 125: Qubit(QuantumRegister(127, 'q'), 124),
# 123: Qubit(QuantumRegister(127, 'q'), 125),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 123: Qubit(QuantumRegister(127, 'q'), 123),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 125),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), None, Layout({
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 1: Qubit(QuantumRegister(127, 'q'), 1),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 3: Qubit(QuantumRegister(127, 'q'), 3),
# 4: Qubit(QuantumRegister(127, 'q'), 4),
# 5: Qubit(QuantumRegister(127, 'q'), 5),
# 6: Qubit(QuantumRegister(127, 'q'), 6),
# 7: Qubit(QuantumRegister(127, 'q'), 7),
# 8: Qubit(QuantumRegister(127, 'q'), 8),
# 9: Qubit(QuantumRegister(127, 'q'), 9),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 15: Qubit(QuantumRegister(127, 'q'), 15),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 21: Qubit(QuantumRegister(127, 'q'), 21),
# 22: Qubit(QuantumRegister(127, 'q'), 22),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 123: Qubit(QuantumRegister(127, 'q'), 125),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 125: Qubit(QuantumRegister(127, 'q'), 124),
# 124: Qubit(QuantumRegister(127, 'q'), 123),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# })]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 15
#      13 # Write to JSON file
#      14 with open('data19sep.json', 'w') as f:
# ---> 15     json.dump(data, f, indent=4)
#
# File C:\python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File C:\python311\Lib\json\encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File C:\python311\Lib\json\encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File C:\python311\Lib\json\encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File C:\python311\Lib\json\encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File C:\python311\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Layout is not JSON serializable

# %%
import json
import qiskit.qasm3
import base64

#Static and plugin modified circuit
qc = get_ghz_circ_static(num_qubit=7)
qc1 = get_ghz_circ_dynamic_2(num_qubit=7)

# Convert plot image to Base64
with open("ghz_graph19_sep.png", "w") as f:
#    plot_data = base64.b64encode(f.read()).decode('utf-8')

# Convert to a dictionary
# qc_dict = qc.to_dict()
# "Mnimum qubit number:": result_metric_real['usage']['seconds'],

data = {
    "Hardware_name:": backend_name,
    "Static circuit:": qiskit.qasm3.dumps(qc),
    "Plugin modified circuit:": qiskit.qasm3.dumps(qc1),
    "Qubit number list:": num_qubit_list,
    "Total copies:": copies,
    "Ideal simulator results:": counts_list_ideal,
    "Job Id:": job.job_id(),
    "Job metrics": result_metric_real,
   # "DD pulse:": options.dynamical_decoupling.sequence_type,
    "Real hardware results:": counts_list_real,
    "Mean plots static circuit:": y1_static,
    "Mean plots plugin modified circuit:": y1_dynamic_2,
    "Error plots static circuit:": y_error_static,
    "Error plots plugin modified circuit:": y_error_dynamic_2,
    "plot": plot_data
}


"""
with open("ghz_test.json", "w") as f:
    json.dump(data, f, indent=4)
"""
# Out:
#   Cell In[45], line 17
#     data = {
#     ^
# IndentationError: expected an indented block after 'with' statement on line 10
